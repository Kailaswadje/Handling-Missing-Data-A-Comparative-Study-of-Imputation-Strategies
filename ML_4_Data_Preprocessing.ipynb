# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\wadje\Desktop\Learnbay\LearnBay_Dataset\Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# cabin has 77 % data is missing so we can go for drop the columns

# %%
df = df.drop(['Cabin'], axis = 1)

# %%
df.isnull().sum()/len(df) * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
df['Embarked'].value_counts() # categorical data - so we can use the mode
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# PassengerId     0.00000
# Survived        0.00000
# Pclass          0.00000
# Name            0.00000
# Sex             0.00000
# Age            19.86532
# SibSp           0.00000
# Parch           0.00000
# Ticket          0.00000
# Fare            0.00000
# Embarked        0.00000
# dtype: float64

# %%
# Handling of numerical data - age

# %%
sns.boxplot(y = 'Age',data = df)
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()/len(df) * 100
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
#Arbitary value imputation

# %%
df1 = pd.read_csv(r"C:\Users\wadje\Desktop\Learnbay\LearnBay_Dataset\Titanic-Dataset.csv")

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1 = df1.drop(['Cabin'], axis = 1)

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1.drop(columns = ['Survived'])
y = df1['Survived']

# %%
x.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='str')

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='str')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
x_train['Age_999'] = x_train['Age'].fillna(9999)

# %%
x_train['Age_minus1'] = x_train['Age'].fillna(-1)

# %%
x_train.head()
# Out:
#      PassengerId  Pclass                             Name     Sex   Age  \
# 105          106       3            Mionoff, Mr. Stoytcho    male  28.0
# 68            69       3  Andersson, Miss. Erna Alexandra  female  17.0
# 253          254       3         Lobb, Mr. William Arthur    male  30.0
# 320          321       3               Dennis, Mr. Samuel    male  22.0
# 706          707       2    Kelly, Mrs. Florence "Fannie"  female  45.0
#
#      SibSp  Parch     Ticket     Fare Embarked  Age_999  Age_minus1
# 105      0      0     349207   7.8958        S     28.0        28.0
# 68       4      2    3101281   7.9250        S     17.0        17.0
# 253      1      0  A/5. 3336  16.1000        S     30.0        30.0
# 320      0      0  A/5 21172   7.2500        S     22.0        22.0
# 706      0      0     223596  13.5000        S     45.0        45.0

# %%
x_train.to_csv('train_test.csv')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x_train['Age'].plot(kind = 'kde', ax = ax, color = 'blue')
x_train['Age_999'].plot(kind = 'kde', ax = ax, color = 'red')
x_train['Age_minus1'].plot(kind = 'kde', ax = ax, color = 'green')

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc = 'best')
